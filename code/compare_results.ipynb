# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
networks = [i for i in range(1,31) if i not in [5, 15, 17, 26, 27]]

def read_file(path):
    extension = path[2:].split('.')[1]
    if extension == 'int':
        with open(path) as file:
            return int(file.read())
    elif extension == 'float':
        with open(path) as file:
            return float(file.read())
    else:
        raise Exception(f'{extension=}')

def get_stats(network: int):
    j_properties_dir = f'/data/s1620444/{network:02}/properties/'
    properties = {prop.split('.')[0]: read_file(j_properties_dir + prop) 
                  for prop 
                  in ['edges.int', 'connected_pairs.int', 'I_LogisticRegression.float','II-A_LogisticRegression.float', 'II-B_LogisticRegression.float','III-A_LogisticRegression.float', 'III-B_LogisticRegression.float','I+II-A+III-A_LogisticRegression.float']}    
    return {
        '\\bar e': properties['edges'] / properties['connected_pairs'],
        'I': properties['I_LogisticRegression'],
        'II-A': properties['II-A_LogisticRegression'],
        'II-B': properties['II-B_LogisticRegression'],
        'III-A': properties['III-A_LogisticRegression'],
        'III-B': properties['III-B_LogisticRegression'],
        'I+II-A+III-A': properties['I+II-A+III-A_LogisticRegression'],
        'Domain': pd.read_json('../networks.jsonl', lines=True).set_index('index').loc[network, 'category']
    }

# %%
data = pd.DataFrame({network: get_stats(network) for network in networks}).T.astype({'\\bar e': float, 'I': float, 'II-A': float, 'II-B': float, 'III-A': float, 'III-B': float,'I+II-A+III-A':float})

# %%
data
# Out:
#        \bar e         I      II-A      II-B     III-A     III-B  I+II-A+III-A  \
# 1    3.533745  0.860351  0.904898  0.894399  0.907948  0.857762      0.921005
# 2    1.944224  0.643558  0.765596  0.757134  0.819852  0.744469      0.833159
# 3    3.815657  0.936551  0.948368  0.944988  0.963494  0.952577      0.969585
# 4    1.000000  0.728765  0.769349  0.768443  0.791145  0.719079      0.804380
# 6    1.353547  0.703448  0.776949  0.758817  0.813560  0.761176      0.833383
# 7    7.082018  0.775300  0.855791  0.847219  0.859803  0.752013      0.878876
# 8    1.000000  0.728765  0.769349  0.768443  0.791145  0.719079      0.804380
# 9    1.012307  0.975523  0.971939  0.973323  0.977227  0.901945      0.984600
# 10   1.118615  0.952119  0.965303  0.959477  0.967706  0.957952      0.976524
# 11   1.009547  0.852811  0.866315  0.858069  0.888296  0.781113      0.905191
# 12  25.500308  0.699492  0.812013  0.767866  0.841924  0.666426      0.888889
# 13   4.793275  0.839338  0.870506  0.852903  0.955589  0.708377      0.963270
# 14   2.076968  0.857515  0.930527  0.928284  0.972879  0.935414      0.976381
# 16   1.199161  0.942167  0.955798  0.955400  0.973705  0.958796      0.977299
# 18   1.746068  0.937477  0.960361  0.958571  0.970832  0.946568      0.974752
# 19   8.535812  0.919495  0.930159  0.920705  0.957225  0.914528      0.961594
# 20   1.722823  0.881987  0.941888  0.942082  0.982909  0.947408      0.985708
# 21   1.050273  0.834389  0.837493  0.835273  0.895092  0.810854      0.900966
# 22   1.594635  0.973157  0.983579  0.982238  0.992074  0.970051      0.995986
# 23   1.551617  0.948602  0.967565  0.966238  0.983492  0.953659      0.990355
# 24   1.019506  0.869167  0.916989  0.917304  0.964797  0.944468      0.974774
# 25   1.438842  0.914718  0.943264  0.937678  0.970693  0.929991      0.979583
# 28   2.257692  0.879041  0.907748  0.897438  0.930029  0.903941      0.940333
# 29   2.460012  0.892679  0.913372  0.907771  0.938721  0.917199      0.947102
# 30  20.688123  0.726061  0.810901  0.779280  0.808518  0.722456      0.849712
#
#            Domain
# 1          Social
# 2     Information
# 3          Social
# 4          Social
# 6     Information
# 7          Social
# 8          Social
# 9          Social
# 10         Social
# 11    Information
# 12         Social
# 13    Information
# 14         Social
# 16         Social
# 18         Social
# 19         Social
# 20         Social
# 21    Information
# 22         Social
# 23         Social
# 24    Information
# 25         Social
# 28  Technological
# 29  Technological
# 30         Social

# %%
network_names = ["FB-w","FB-l","D-rep","D-f",
                "D-v","EP","bitA","bitOT",
                "chess","loans"]
networks = [4,8,9,10,11,16,18,20,21,24]

paper_data = {4:{ "p-I": 0.762, "p-II-A": 0.809,"p-II-B": 0.809, "p-III-A":0.788},
              8: {"p-I": 0.762, "p-II-A": 0.803,"p-II-B": 0.803, "p-III-A":0.775},
              9: {"p-I": 0.837, "p-II-A": 0.866,"p-II-B": 0.866, "p-III-A":0.775},}
# Out:
#       \bar e         I      II-A      II-B     III-A     III-B  I+II-A+III-A  \
# 4   1.000000  0.728765  0.769349  0.768443  0.791145  0.719079      0.804391
# 8   1.000000  0.728765  0.769349  0.768443  0.791145  0.719079      0.804391
# 9   1.012307  0.975523  0.971939  0.973323  0.977227  0.901945      0.984600
# 10  1.118615  0.952119  0.965303  0.959477  0.967706  0.957952      0.976525
# 11  1.009547  0.852811  0.866315  0.858069  0.888296  0.781113      0.905190
# 16  1.199161  0.942167  0.955798  0.955400  0.973705  0.958796      0.977297
# 18  1.746068  0.937477  0.960361  0.958571  0.970832  0.946568      0.974784
# 20  1.722823  0.881987  0.941888  0.942082  0.982909  0.947408      0.985708
# 21  1.050273  0.834389  0.837493  0.835273  0.895092  0.810854      0.900922
# 24  1.019506  0.869167  0.916989  0.917304  0.964797  0.944468      0.974772
#
#          Domain
# 4        Social
# 8        Social
# 9        Social
# 10       Social
# 11  Information
# 16       Social
# 18       Social
# 20       Social
# 21  Information
# 24  Information
